# %% [markdown]
# ## Preamble

# %%
# !curl -s "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %%
from module_update import update, css, code_toggle, printmd

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
update('graph_networkx_louvain')
import nbtext as nb
from nbtext import get_urn, make_graph, get_urn, relaterte_ord, navn, totals
import graph_networkx_louvain as gnl
# %matplotlib inline
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Graphs_words_literature\graph_networkx_louvain.py`

# %% [markdown]
# ### Utility functions

# %%
# tm_red is a reduced token map
coord_name = lambda names, tm_red: [[na for na in names[0] if (na,) in [z[0] for z in tm_red ]]] + [list(set(na) & set([z[0] for z in tm_red])) for na in names[1:]]

token_map_names = lambda tmap: [
    [z[0][0] for z in nb.token_map_to_tuples(tmap) if len(z[0]) == 1]
] + [
    [z[0] for z in nb.token_map_to_tuples(tmap) if len(z[0]) == 2]
] + [
    [z[0] for z in nb.token_map_to_tuples(tmap) if len(z[0]) == 3]
]+ [
    [z[0] for z in nb.token_map_to_tuples(tmap) if len(z[0]) == 4]
]

# create a character network with only tokens in tokenmap
# see nb.make_network_name_graph in nbtext
character_network = lambda urn, tm: nb.make_network_name_graph(urn, token_map_names(tm), tokenmap = nb.token_map_to_tuples(tm))


# edge counts
edge_counts = lambda G, count=1: [edges for edges in G.edges(data=True) if edges[2]['weight'] <= count]

# new edges
remove_edges = lambda G, count=1: [(edges[0], edges[1]) for edges in G.edges(data=True) if edges[2]['weight'] > count]

# %% [markdown]
# ## Name graphs
#
# Here we are looking for Tolstoj's War and Peace

# %%
# Fetch URNs

urns = get_urn({
    'author':'masterson%lou%', 
    'year':1900, 
    'neste':160,
    'limit':100,
    'title':'%%'
    
})
urns
# Out:
# [[2015102208248, 'Masterson, Louis', 'To desperados', 1974],
#  [2007111901048, 'Masterson, Louis', 'Diablo', 1991],
#  [2013040308081, 'Masterson, Louis', 'Texas Ranger', 2010],
#  [2013041608113, 'Masterson, Louis', 'Korset og sverdet', 1978],
#  [2016093048042, 'Masterson, Louis', 'Comanche', 1974],
#  [2016070708023, 'Masterson, Louis', 'Der ørnene dør', 2002],
#  [2013013008176,
#   'Masterson, Louis',
#   'Lovens bøddel ; Djevelens utvalgte',
#   2007],
#  [2013060408200, 'Masterson, Louis', 'Ubåtkontakt', 1980],
#  [2007081700037, 'Masterson, Louis', 'Ingen tårer for Morgan Kane', 1989],
#  [2008082104049, 'Masterson, Louis', 'Lenken og fanen', 1997],
#  [2011062808076,
#   'Masterson, Louis',
#   'Bøddelen fra Guerrero ; Drep for loven',
#   2005],
#  [2013042508135, 'Masterson, Louis', 'Alaska marshal', 1973],
#  [2013042308034, 'Masterson, Louis', "Gringo's hevn", 1970],
#  [2014101308124,
#   'Masterson, Louis',
#   "Klondike '97 ; Dommedag i Skagway",
#   2008],
#  [2013060408158, 'Masterson, Louis', 'Tigeren fra Montana', 1972],
#  [2013070108113, 'Masterson, Louis', "Kane's kvinner", 1974],
#  [2016060108116, 'Masterson, Louis', 'I dragens klør', 1988],
#  [2013042408017, 'Masterson, Louis', 'Tempelprestinnens gjenganger', 1971],
#  [2013120238087, 'Masterson, Louis', 'Gringo', 2010],
#  [2013042508132, 'Masterson, Louis', "I Morgan Kane's fotspor", 1975],
#  [2012031908162, 'Masterson, Louis', 'Blodig jord', 1973],
#  [2015111008045, 'Masterson, Louis', 'Dette er døden, sẽnor Kane', 1980],
#  [2015012048029, 'Masterson, Louis', 'Der ørnene dør', 1986],
#  [2011070405141, 'Masterson, Louis', 'rangers ære ; Morder og marshall', 2003],
#  [2014120208168, 'Masterson, Louis', 'El Gringo vender tilbake', 2010],
#  [2013120238010, 'Masterson, Louis', 'Til siste patron', 1991],
#  [2010093020017, 'Masterson, Louis', 'Express-agent', 1990],
#  [2010112908026, 'Masterson, Louis', 'Riflen som synger', 1990],
#  [2015072108090, 'Masterson, Louis', 'Helvete under null', 1980],
#  [2007052400012, 'Masterson, Louis', 'Udyret fra Yuma', 1972],
#  [2013060408118, 'Masterson, Louis', 'Jungelens lov', 1967],
#  [2016060108119, 'Masterson, Louis', "Kane's likemann", 1970],
#  [2015111008046, 'Masterson, Louis', 'Hevn!', 1972],
#  [2016062708126, 'Masterson, Louis', 'Duell i San Antonio', 1980],
#  [2013042508007, 'Masterson, Louis', 'Duell i Tombstone', 1968],
#  [2016041408019, 'Masterson, Louis', 'Mosquito', 1979],
#  [2010092808042, 'Masterson, Louis', 'Metzgar', 1990],
#  [2015012008079,
#   'Masterson, Louis',
#   'Hevnens engler ; Gribbene i Sierra Madre',
#   2006],
#  [2010112908104, 'Masterson, Louis', 'Revolvergribben', 1990],
#  [2013042338044, 'Masterson, Louis', 'rangers ære', 1967],
#  [2007070300049, 'Masterson, Louis', '"Killer" Kane', 1981],
#  [2009030300083, 'Masterson, Louis', 'Lenken og fanen', 1997],
#  [2007071601101, 'Masterson, Louis', 'Legenden om Morgan Kane', 1973],
#  [2013042338046, 'Masterson, Louis', 'Bøddelen fra Guerrero', 1968],
#  [2013080808047, 'Masterson, Louis', "I Morgan Kane's fotspor", 1980],
#  [2014090308129, 'Masterson, Louis', 'Fem ess i Dodge City', 1989],
#  [2016082908026, 'Masterson, Louis', 'Pistoléro ; Udyret fra Yuma', 2004],
#  [2010080308096, 'Masterson, Louis', 'Bastardene', 1990],
#  [2013080908073, 'Masterson, Louis', 'Fem ess', 1986],
#  [2008060900104, 'Masterson, Louis', 'Mellom liv og død', 1989],
#  [2009011904068, 'Masterson, Louis', 'Korset og sverdet', 1997],
#  [2013042308035, 'Masterson, Louis', "Kane's stjerne", 1985],
#  [2013070108115, 'Masterson, Louis', "Kane's likemann", 1970],
#  [2013092307006, 'Masterson, Louis', 'Der ørnene dør', 1974],
#  [2013070408081, 'Masterson, Louis', 'De dødes dag', 2012],
#  [2013070108110, 'Masterson, Louis', 'Morgan Kane - menneskejeger', 1971],
#  [2010093020018, 'Masterson, Louis', 'Bøddelens tårer', 1990],
#  [2013042508061, 'Masterson, Louis', 'Tilbake til kampen', 1968],
#  [2014012208044, 'Masterson, Louis', 'Ubåt-kontakt', 1991],
#  [2014030606053,
#   'Masterson, Louis',
#   'Satans horn ; Morgan Kane og "The Wild Bunch"',
#   2007],
#  [2014051908121,
#   'Masterson, Louis',
#   'Tigeren fra Montana ; Den gale hunden fra Utah',
#   2007],
#  [2007071901039, 'Masterson, Louis', 'Med revolver og stjerne', 1972],
#  [2013053008091, 'Masterson, Louis', 'Blod og gull', 1969],
#  [2008081404080, 'Masterson, Louis', 'Stormens øye', 1997],
#  [2013042508063, 'Masterson, Louis', 'Høyt spill i New Orleans', 1969],
#  [2014022806061,
#   'Masterson, Louis',
#   'Solen stod stille over Little Bighorn',
#   1976],
#  [2014070106118, 'Masterson, Louis', 'siste cheyenne', 1974],
#  [2013053008120, 'Masterson, Louis', 'Med revolver og stjerne', 1966],
#  [2013042508139, 'Masterson, Louis', 'Demonen fra Nicaragua', 1970],
#  [2012062205112, 'Masterson, Louis', 'Morgan Kane og smuglerne', 2010],
#  [2013042508138, 'Masterson, Louis', 'Hevnens engler', 1970],
#  [2013042408022, 'Masterson, Louis', 'Lovens bøddel', 1974],
#  [2013042508062, 'Masterson, Louis', 'Bravado', 1968],
#  [2013042508141, 'Masterson, Louis', 'Galge-ekspressen', 1968],
#  [2013042308043, 'Masterson, Louis', 'Pistoléro', 1967],
#  [2011100408229,
#   'Masterson, Louis',
#   'Bandidos Yanqui ; Den siste jakten',
#   2008],
#  [2014062405095, 'Masterson, Louis', 'Dette er døden, señor Kane', 2011],
#  [2013041908146, 'Masterson, Louis', 'Drep for loven', 1968],
#  [2009012204004,
#   'Masterson, Louis',
#   'I Morgan Kanes fotspor ; Blodsporet til Santa Fe',
#   2002],
#  [2013042508133, 'Masterson, Louis', 'Dommedag i Skagway', 1973],
#  [2016072808038,
#   'Masterson, Louis',
#   'Mellom liv og død ; Tilbake til kampen',
#   2004],
#  [2007081501041, 'Masterson, Louis', 'Bonanza Kid', 1991],
#  [2014100238011,
#   'Masterson, Louis',
#   'Gringo vender tilbake ; To desperados',
#   2003],
#  [2014021806097, 'Masterson, Louis', 'Blodsporet til Santa Fe', 2009],
#  [2008020501030, 'Masterson, Louis', 'Askeneven', 1994],
#  [2007080101071, 'Masterson, Louis', 'Gringo', 1970],
#  [2014080508030, 'Masterson, Louis', 'Bøffelkrigen', 2010],
#  [2013092606024, 'Masterson, Louis', 'Revolvermanns arv', 2012],
#  [2013071208061, 'Masterson, Louis', 'Hevn!', 2011],
#  [2009012600018, 'Masterson, Louis', 'Gringo ; El Gringos hevn', 2002],
#  [2013042338049, 'Masterson, Louis', 'colt til señora', 1972],
#  [2007072004059, 'Masterson, Louis', 'Storm over Sonora', 1972],
#  [2013041908138, 'Masterson, Louis', "Klondike '97", 1973],
#  [2016060108118, 'Masterson, Louis', 'Slavenes kyst', 1974],
#  [2013042408102, 'Masterson, Louis', 'Bøffelkrigen', 1971],
#  [2013042508142, 'Masterson, Louis', 'Oklahoma terror', 1971],
#  [2013022206019, 'Masterson, Louis', 'siste cheyenne', 2009],
#  [2013041908139, 'Masterson, Louis', 'Rio Grande', 1968],
#  [2014081908138,
#   'Masterson, Louis',
#   'Tempelprestinnens gjenganger ; Hevneren fra Tombstone',
#   2007],
#  [2013041908142, 'Masterson, Louis', 'Slavenes kyst', 1971]]

# %% [markdown]
# The largest seems to be 2011061508082, so we use that one.

# %%
BOOK = 2008082104049

# %% [markdown]
# ## Find names, everything with capital letters...

# %% [markdown]
# Command for finding names is `names()`. It returns a tuple of name sequences, we only use single names for this part, so select the first part.

# %%
wp = nb.names(BOOK, cutoff=3)
print(wp)
# Out:
# (Counter({'Pla': 134, 'El': 125, 'Låra': 81, 'Sanchez': 78, 'Jefe': 55, 'Valle': 40, 'Royal': 37, 'Hule': 32, 'Peter': 30, 'Senor': 30, 'Herrera': 28, 'Mirador': 28, 'Mexico': 25, 'Tuztepec': 24, 'Hondura': 23, 'Nanche': 20, 'Cordoba': 17, 'Ja': 17, 'Kom': 17, 'City': 15, 'Hermosillo': 15, 'Takk': 13, 'Balsa': 12, 'Er': 12, 'Tresgallo': 12, 'Diablito': 10, 'Kan': 8, 'Maria': 8, 'Pedrito': 8, 'Ta': 8, 'Veracruz': 8, 'Godt': 7, 'Hermanos': 7, 'Hold': 7, 'Lara': 7, 'Dem': 6, 'Lesaca': 6, 'Michelangelo': 6, 'Silveti': 6, 'Theresa': 6, 'Veronica': 6, 'Hermanos-brødrene': 5, 'Hm': 5, 'Nådens': 5, 'Deres': 4, 'Din': 4, 'Hjelp': 4, 'Joaquin': 4, 'Luis': 4, 'Madonna': 4, 'Mendez': 4, 'Nr': 4, 'Si': 4, 'Unnskyld': 4}), Counter({('El', 'Jefe'): 54, ('Valle', 'Royal'): 37, ('El', 'Hule'): 32, ('El', 'Mirador'): 28, ('Mexico', 'City'): 15, ('Senor', 'Sanchez'): 8, ('El', 'Diablito'): 8, ('Balsa', 'Hermanos'): 6, ('Theresa', 'Maria'): 5, ('Senor', 'Pla'): 4, ('Luis', 'Lesaca'): 4, ('Balsa', 'Hermanos-brødrene'): 2, ('Maria', 'Sanchez'): 2, ('Maria', 'Theresa'): 1, ('Maria', 'Silveti'): 1}), Counter({('Theresa', 'Maria', 'Silveti'): 1}), Counter())

# %% [markdown]
# ## Check some names with concordance
#
# ## Only single word names can be checked (multi word in the making....)

# %%
nb.urn_concordance(urns=BOOK, word='Theresa')
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082104049?searchText=Theresa' target='_blank' style='text-decoration:none'>Lenken og fanen, Masterson, Louis, 1997</a>
#                 </td>
#                 <td>henne i armene sine ,</td>
#                 <td>Theresa</td>
#                 <td style='text-align:left'>Maria . Så gled hun</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082104049?searchText=Theresa' target='_blank' style='text-decoration:none'>Lenken og fanen, Masterson, Louis, 1997</a>
#                 </td>
#                 <td>snakke : Antonio Silveti ,</td>
#                 <td>Theresa</td>
#                 <td style='text-align:left'>Maria ' s ektemann. Øynene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082104049?searchText=Theresa' target='_blank' style='text-decoration:none'>Lenken og fanen, Masterson, Louis, 1997</a>
#                 </td>
#                 <td>forholdet mellom Paco og Maria</td>
#                 <td>Theresa</td>
#                 <td style='text-align:left'>, og som en ekte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082104049?searchText=Theresa' target='_blank' style='text-decoration:none'>Lenken og fanen, Masterson, Louis, 1997</a>
#                 </td>
#                 <td>Hun minnet ham litt om</td>
#                 <td>Theresa</td>
#                 <td style='text-align:left'>Maria Silveti , Antonio^ hustru</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082104049?searchText=Theresa' target='_blank' style='text-decoration:none'>Lenken og fanen, Masterson, Louis, 1997</a>
#                 </td>
#                 <td>Silveti var der , og</td>
#                 <td>Theresa</td>
#                 <td style='text-align:left'>Maria , hans hustru .</td>
#             </tr>
# </table>

# %% [markdown]
# ## check tokens with command `nb.token_map(character_names, strings = Bool)` the value of parameter `strings` can be `True` or `False`, default is `False` :

# %%
nb.token_map(wp)
# Out:
# [(('Balsa',), ('Balsa', 'Hermanos-brødrene')),
#  (('City',), ('Mexico', 'City')),
#  (('Cordoba',), ('Cordoba',)),
#  (('Dem',), ('Dem',)),
#  (('Deres',), ('Deres',)),
#  (('Diablito',), ('El', 'Diablito')),
#  (('Din',), ('Din',)),
#  (('El',), ('El', 'Hule')),
#  (('Er',), ('Er',)),
#  (('Godt',), ('Godt',)),
#  (('Hermanos',), ('Balsa', 'Hermanos')),
#  (('Hermanos-brødrene',), ('Balsa', 'Hermanos-brødrene')),
#  (('Hermosillo',), ('Hermosillo',)),
#  (('Herrera',), ('Herrera',)),
#  (('Hjelp',), ('Hjelp',)),
#  (('Hm',), ('Hm',)),
#  (('Hold',), ('Hold',)),
#  (('Hondura',), ('Hondura',)),
#  (('Hule',), ('El', 'Hule')),
#  (('Ja',), ('Ja',)),
#  (('Jefe',), ('El', 'Jefe')),
#  (('Joaquin',), ('Joaquin',)),
#  (('Kan',), ('Kan',)),
#  (('Kom',), ('Kom',)),
#  (('Lara',), ('Lara',)),
#  (('Lesaca',), ('Luis', 'Lesaca')),
#  (('Luis',), ('Luis', 'Lesaca')),
#  (('Låra',), ('Låra',)),
#  (('Madonna',), ('Madonna',)),
#  (('Maria',), ('Theresa', 'Maria', 'Silveti')),
#  (('Mendez',), ('Mendez',)),
#  (('Mexico',), ('Mexico', 'City')),
#  (('Michelangelo',), ('Michelangelo',)),
#  (('Mirador',), ('El', 'Mirador')),
#  (('Nanche',), ('Nanche',)),
#  (('Nr',), ('Nr',)),
#  (('Nådens',), ('Nådens',)),
#  (('Pedrito',), ('Pedrito',)),
#  (('Peter',), ('Peter',)),
#  (('Pla',), ('Senor', 'Pla')),
#  (('Royal',), ('Valle', 'Royal')),
#  (('Sanchez',), ('Maria', 'Sanchez')),
#  (('Senor',), ('Senor', 'Sanchez')),
#  (('Si',), ('Si',)),
#  (('Silveti',), ('Theresa', 'Maria', 'Silveti')),
#  (('Ta',), ('Ta',)),
#  (('Takk',), ('Takk',)),
#  (('Theresa',), ('Theresa', 'Maria', 'Silveti')),
#  (('Tresgallo',), ('Tresgallo',)),
#  (('Tuztepec',), ('Tuztepec',)),
#  (('Unnskyld',), ('Unnskyld',)),
#  (('Valle',), ('Valle', 'Royal')),
#  (('Veracruz',), ('Veracruz',)),
#  (('Veronica',), ('Veronica',)),
#  (('Valle', 'Royal'), ('Valle', 'Royal')),
#  (('El', 'Hule'), ('El', 'Hule')),
#  (('Balsa', 'Hermanos-brødrene'), ('Balsa', 'Hermanos-brødrene')),
#  (('Balsa', 'Hermanos'), ('Balsa', 'Hermanos')),
#  (('Mexico', 'City'), ('Mexico', 'City')),
#  (('Maria', 'Sanchez'), ('Maria', 'Sanchez')),
#  (('Theresa', 'Maria'), ('Theresa', 'Maria', 'Silveti')),
#  (('Senor', 'Sanchez'), ('Senor', 'Sanchez')),
#  (('El', 'Mirador'), ('El', 'Mirador')),
#  (('Senor', 'Pla'), ('Senor', 'Pla')),
#  (('Luis', 'Lesaca'), ('Luis', 'Lesaca')),
#  (('El', 'Diablito'), ('El', 'Diablito')),
#  (('Maria', 'Theresa'), ('Theresa', 'Maria', 'Silveti')),
#  (('Maria', 'Silveti'), ('Theresa', 'Maria', 'Silveti')),
#  (('El', 'Jefe'), ('El', 'Jefe')),
#  (('Theresa', 'Maria', 'Silveti'), ('Theresa', 'Maria', 'Silveti'))]

# %%
nb.token_map(wp, strings=True)
# Out:
# ['Balsa ==> Balsa_Hermanos-brødrene',
#  'City ==> Mexico_City',
#  'Cordoba ==> Cordoba',
#  'Dem ==> Dem',
#  'Deres ==> Deres',
#  'Diablito ==> El_Diablito',
#  'Din ==> Din',
#  'El ==> El_Hule',
#  'Er ==> Er',
#  'Godt ==> Godt',
#  'Hermanos ==> Balsa_Hermanos',
#  'Hermanos-brødrene ==> Balsa_Hermanos-brødrene',
#  'Hermosillo ==> Hermosillo',
#  'Herrera ==> Herrera',
#  'Hjelp ==> Hjelp',
#  'Hm ==> Hm',
#  'Hold ==> Hold',
#  'Hondura ==> Hondura',
#  'Hule ==> El_Hule',
#  'Ja ==> Ja',
#  'Jefe ==> El_Jefe',
#  'Joaquin ==> Joaquin',
#  'Kan ==> Kan',
#  'Kom ==> Kom',
#  'Lara ==> Lara',
#  'Lesaca ==> Luis_Lesaca',
#  'Luis ==> Luis_Lesaca',
#  'Låra ==> Låra',
#  'Madonna ==> Madonna',
#  'Maria ==> Theresa_Maria_Silveti',
#  'Mendez ==> Mendez',
#  'Mexico ==> Mexico_City',
#  'Michelangelo ==> Michelangelo',
#  'Mirador ==> El_Mirador',
#  'Nanche ==> Nanche',
#  'Nr ==> Nr',
#  'Nådens ==> Nådens',
#  'Pedrito ==> Pedrito',
#  'Peter ==> Peter',
#  'Pla ==> Senor_Pla',
#  'Royal ==> Valle_Royal',
#  'Sanchez ==> Maria_Sanchez',
#  'Senor ==> Senor_Sanchez',
#  'Si ==> Si',
#  'Silveti ==> Theresa_Maria_Silveti',
#  'Ta ==> Ta',
#  'Takk ==> Takk',
#  'Theresa ==> Theresa_Maria_Silveti',
#  'Tresgallo ==> Tresgallo',
#  'Tuztepec ==> Tuztepec',
#  'Unnskyld ==> Unnskyld',
#  'Valle ==> Valle_Royal',
#  'Veracruz ==> Veracruz',
#  'Veronica ==> Veronica',
#  'Valle_Royal ==> Valle_Royal',
#  'El_Hule ==> El_Hule',
#  'Balsa_Hermanos-brødrene ==> Balsa_Hermanos-brødrene',
#  'Balsa_Hermanos ==> Balsa_Hermanos',
#  'Mexico_City ==> Mexico_City',
#  'Maria_Sanchez ==> Maria_Sanchez',
#  'Theresa_Maria ==> Theresa_Maria_Silveti',
#  'Senor_Sanchez ==> Senor_Sanchez',
#  'El_Mirador ==> El_Mirador',
#  'Senor_Pla ==> Senor_Pla',
#  'Luis_Lesaca ==> Luis_Lesaca',
#  'El_Diablito ==> El_Diablito',
#  'Maria_Theresa ==> Theresa_Maria_Silveti',
#  'Maria_Silveti ==> Theresa_Maria_Silveti',
#  'El_Jefe ==> El_Jefe',
#  'Theresa_Maria_Silveti ==> Theresa_Maria_Silveti']

# %% [markdown]
# ## There are three commands for creating a graph
#
# ### Make a network using a a list of words applied to a book
# ### `nb.make_network(bookref, list_of_words)`
#
# ### Network with a set of tokens (from `nb.names`), and an optional token map, cutoff is also optional
# ###  `nb.make_network_name_graph(bookref, tokens, token_map, cutoff)`
#
# ### Network using values from token_map. Only tokens in the token map are analyzed
# ###  `character_network(bookref, tokens, token_map)`

# %%
# Here we create a list of tokens
graf = nb.make_network(BOOK, list(wp[0].keys()))

# %% [markdown]
# # Draw graph with `gnl.show_graph(Graph, spread=0.2)`

# %%
gnl.show_graph(graf, spread=1.8)

# %%
g2 = nb.make_network_name_graph(BOOK, wp, cutoff = 5)

# %%
gnl.show_graph(g2)

# %% [markdown]
# # Draw with an edited token map

# %%
tokenmap = nb.token_map(wp, strings=True)
tokenmap
# Out:
# ['Balsa ==> Balsa_Hermanos-brødrene',
#  'City ==> Mexico_City',
#  'Cordoba ==> Cordoba',
#  'Dem ==> Dem',
#  'Deres ==> Deres',
#  'Diablito ==> El_Diablito',
#  'Din ==> Din',
#  'El ==> El_Hule',
#  'Er ==> Er',
#  'Godt ==> Godt',
#  'Hermanos ==> Balsa_Hermanos',
#  'Hermanos-brødrene ==> Balsa_Hermanos-brødrene',
#  'Hermosillo ==> Hermosillo',
#  'Herrera ==> Herrera',
#  'Hjelp ==> Hjelp',
#  'Hm ==> Hm',
#  'Hold ==> Hold',
#  'Hondura ==> Hondura',
#  'Hule ==> El_Hule',
#  'Ja ==> Ja',
#  'Jefe ==> El_Jefe',
#  'Joaquin ==> Joaquin',
#  'Kan ==> Kan',
#  'Kom ==> Kom',
#  'Lara ==> Lara',
#  'Lesaca ==> Luis_Lesaca',
#  'Luis ==> Luis_Lesaca',
#  'Låra ==> Låra',
#  'Madonna ==> Madonna',
#  'Maria ==> Theresa_Maria_Silveti',
#  'Mendez ==> Mendez',
#  'Mexico ==> Mexico_City',
#  'Michelangelo ==> Michelangelo',
#  'Mirador ==> El_Mirador',
#  'Nanche ==> Nanche',
#  'Nr ==> Nr',
#  'Nådens ==> Nådens',
#  'Pedrito ==> Pedrito',
#  'Peter ==> Peter',
#  'Pla ==> Senor_Pla',
#  'Royal ==> Valle_Royal',
#  'Sanchez ==> Maria_Sanchez',
#  'Senor ==> Senor_Sanchez',
#  'Si ==> Si',
#  'Silveti ==> Theresa_Maria_Silveti',
#  'Ta ==> Ta',
#  'Takk ==> Takk',
#  'Theresa ==> Theresa_Maria_Silveti',
#  'Tresgallo ==> Tresgallo',
#  'Tuztepec ==> Tuztepec',
#  'Unnskyld ==> Unnskyld',
#  'Valle ==> Valle_Royal',
#  'Veracruz ==> Veracruz',
#  'Veronica ==> Veronica',
#  'Valle_Royal ==> Valle_Royal',
#  'El_Hule ==> El_Hule',
#  'Balsa_Hermanos-brødrene ==> Balsa_Hermanos-brødrene',
#  'Balsa_Hermanos ==> Balsa_Hermanos',
#  'Mexico_City ==> Mexico_City',
#  'Maria_Sanchez ==> Maria_Sanchez',
#  'Theresa_Maria ==> Theresa_Maria_Silveti',
#  'Senor_Sanchez ==> Senor_Sanchez',
#  'El_Mirador ==> El_Mirador',
#  'Senor_Pla ==> Senor_Pla',
#  'Luis_Lesaca ==> Luis_Lesaca',
#  'El_Diablito ==> El_Diablito',
#  'Maria_Theresa ==> Theresa_Maria_Silveti',
#  'Maria_Silveti ==> Theresa_Maria_Silveti',
#  'El_Jefe ==> El_Jefe',
#  'Theresa_Maria_Silveti ==> Theresa_Maria_Silveti']

# %% [markdown]
# ## copy the output from above an prepare it for edits:

# %%
name_edits = ['Balsa ==> Balsa_Hermanos-brødrene',
 'City ==> Mexico_City',
 'Cordoba ==> Cordoba',
 #'Dem ==> Dem',
 #'Deres ==> Deres',
 'Diablito ==> El_Diablito',
 #'Din ==> Din',
 'El ==> El_Hule',
 #'Er ==> Er',
 #'Godt ==> Godt',
 'Hermanos ==> Balsa_Hermanos',
 'Hermanos-brødrene ==> Balsa_Hermanos-brødrene',
 'Hermosillo ==> Hermosillo',
 'Herrera ==> Herrera',
 #'Hjelp ==> Hjelp',
 #'Hm ==> Hm',
 #'Hold ==> Hold',
 'Hondura ==> Hondura',
 'Hule ==> El_Hule',
 #'Ja ==> Ja',
 'Jefe ==> El_Jefe',
 'Joaquin ==> Joaquin',
 #'Kan ==> Kan',
 #'Kom ==> Kom',
 'Lara ==> Lara',
 'Lesaca ==> Luis_Lesaca',
 'Luis ==> Luis_Lesaca',
 'Låra ==> Låra',
 'Madonna ==> Madonna',
 'Maria ==> Theresa_Maria_Silveti',
 'Mendez ==> Mendez',
 'Mexico ==> Mexico_City',
 'Michelangelo ==> Michelangelo',
 'Mirador ==> El_Mirador',
 'Nanche ==> Nanche',
 #'Nr ==> Nr',
 'Nådens ==> Nådens',
 'Pedrito ==> Pedrito',
 'Peter ==> Peter',
 'Pla ==> Senor_Pla',
 'Royal ==> Valle_Royal',
 'Sanchez ==> Maria_Sanchez',
 'Senor ==> Senor_Sanchez',
 #'Si ==> Si',
 'Silveti ==> Theresa_Maria_Silveti',
 #'Ta ==> Ta',
 #'Takk ==> Takk',
 'Theresa ==> Theresa_Maria_Silveti',
 'Tresgallo ==> Tresgallo',
 'Tuztepec ==> Tuztepec',
 #'Unnskyld ==> Unnskyld',
 'Valle ==> Valle_Royal',
 'Veracruz ==> Veracruz',
 'Veronica ==> Veronica',
 'Valle_Royal ==> Valle_Royal',
 'El_Hule ==> El_Hule',
 'Balsa_Hermanos-brødrene ==> Balsa_Hermanos-brødrene',
 'Balsa_Hermanos ==> Balsa_Hermanos',
 'Mexico_City ==> Mexico_City',
 'Maria_Sanchez ==> Maria_Sanchez',
 'Theresa_Maria ==> Theresa_Maria_Silveti',
 'Senor_Sanchez ==> Senor_Sanchez',
 'El_Mirador ==> El_Mirador',
 'Senor_Pla ==> Senor_Pla',
 'Luis_Lesaca ==> Luis_Lesaca',
 'El_Diablito ==> El_Diablito',
 'Maria_Theresa ==> Theresa_Maria_Silveti',
 'Maria_Silveti ==> Theresa_Maria_Silveti',
 'El_Jefe ==> El_Jefe',
 'Theresa_Maria_Silveti ==> Theresa_Maria_Silveti']

# %%
token_map_names(name_edits)
# Out:
# [['Balsa',
#   'City',
#   'Cordoba',
#   'Diablito',
#   'El',
#   'Hermanos',
#   'Hermanos-brødrene',
#   'Hermosillo',
#   'Herrera',
#   'Hondura',
#   'Hule',
#   'Jefe',
#   'Joaquin',
#   'Lara',
#   'Lesaca',
#   'Luis',
#   'Låra',
#   'Madonna',
#   'Maria',
#   'Mendez',
#   'Mexico',
#   'Michelangelo',
#   'Mirador',
#   'Nanche',
#   'Nådens',
#   'Pedrito',
#   'Peter',
#   'Pla',
#   'Royal',
#   'Sanchez',
#   'Senor',
#   'Silveti',
#   'Theresa',
#   'Tresgallo',
#   'Tuztepec',
#   'Valle',
#   'Veracruz',
#   'Veronica'],
#  [('Valle', 'Royal'),
#   ('El', 'Hule'),
#   ('Balsa', 'Hermanos-brødrene'),
#   ('Balsa', 'Hermanos'),
#   ('Mexico', 'City'),
#   ('Maria', 'Sanchez'),
#   ('Theresa', 'Maria'),
#   ('Senor', 'Sanchez'),
#   ('El', 'Mirador'),
#   ('Senor', 'Pla'),
#   ('Luis', 'Lesaca'),
#   ('El', 'Diablito'),
#   ('Maria', 'Theresa'),
#   ('Maria', 'Silveti'),
#   ('El', 'Jefe')],
#  [('Theresa', 'Maria', 'Silveti')],
#  []]

# %%
g_edits = character_network(BOOK,  name_edits)

# %%
gnl.show_graph(g_edits)

# %% [markdown]
# Growth diagrams plot the sequential development of the characters. Experiment with different values of parameters.

# %%
g2.edges(data=True)
# Out:
# EdgeDataView([('Balsa_Hermanos', 'Balsa_Hermanos-brødrene', {'weight': 8.0}), ('Balsa_Hermanos-brødrene', 'El_Hule', {'weight': 6.0}), ('Balsa_Hermanos-brødrene', 'Senor_Pla', {'weight': 8.0}), ('El_Hule', 'Cordoba', {'weight': 16.0}), ('El_Hule', 'El_Diablito', {'weight': 11.0}), ('El_Hule', 'El_Jefe', {'weight': 71.0}), ('El_Hule', 'El_Mirador', {'weight': 32.0}), ('El_Hule', 'Herrera', {'weight': 8.0}), ('El_Hule', 'Hondura', {'weight': 8.0}), ('El_Hule', 'Ja', {'weight': 6.0}), ('El_Hule', 'Låra', {'weight': 14.0}), ('El_Hule', 'Maria_Sanchez', {'weight': 8.0}), ('El_Hule', 'Mexico_City', {'weight': 13.0}), ('El_Hule', 'Nanche', {'weight': 8.0}), ('El_Hule', 'Peter', {'weight': 6.0}), ('El_Hule', 'Senor_Pla', {'weight': 27.0}), ('El_Hule', 'Theresa_Maria_Silveti', {'weight': 6.0}), ('El_Hule', 'Tuztepec', {'weight': 24.0}), ('El_Hule', 'Valle_Royal', {'weight': 20.0}), ('El_Hule', 'Veronica', {'weight': 6.0}), ('Senor_Pla', 'El_Mirador', {'weight': 16.0}), ('Senor_Pla', 'Herrera', {'weight': 8.0}), ('Senor_Pla', 'Hondura', {'weight': 7.0}), ('Senor_Pla', 'Låra', {'weight': 26.0}), ('Senor_Pla', 'Maria_Sanchez', {'weight': 13.0}), ('Senor_Pla', 'Mexico_City', {'weight': 13.0}), ('Senor_Pla', 'Nanche', {'weight': 6.0}), ('Senor_Pla', 'Peter', {'weight': 10.0}), ('Senor_Pla', 'Senor_Sanchez', {'weight': 8.0}), ('Senor_Pla', 'Tresgallo', {'weight': 17.0}), ('Senor_Pla', 'Valle_Royal', {'weight': 22.0}), ('Cordoba', 'Tresgallo', {'weight': 7.0}), ('Cordoba', 'Valle_Royal', {'weight': 6.0}), ('Tresgallo', 'Valle_Royal', {'weight': 8.0}), ('Valle_Royal', 'El_Mirador', {'weight': 6.0}), ('Valle_Royal', 'Hondura', {'weight': 10.0}), ('Valle_Royal', 'Låra', {'weight': 6.0}), ('Valle_Royal', 'Mexico_City', {'weight': 12.0}), ('Valle_Royal', 'Nanche', {'weight': 8.0}), ('Valle_Royal', 'Theresa_Maria_Silveti', {'weight': 12.0}), ('El_Jefe', 'Maria_Sanchez', {'weight': 6.0}), ('El_Mirador', 'Låra', {'weight': 13.0}), ('El_Mirador', 'Peter', {'weight': 6.0}), ('Hondura', 'Nanche', {'weight': 19.0}), ('Låra', 'Mexico_City', {'weight': 8.0}), ('Låra', 'Peter', {'weight': 31.0}), ('Låra', 'Senor_Sanchez', {'weight': 10.0}), ('Maria_Sanchez', 'Mexico_City', {'weight': 6.0}), ('Maria_Sanchez', 'Senor_Sanchez', {'weight': 12.0}), ('Veronica', 'Michelangelo', {'weight': 6.0})])

# %% [markdown]
# ## Check if there are edges below a certain count

# %%
edge_counts(g2, 6)
# Out:
# [('Balsa_Hermanos-brødrene', 'El_Hule', {'weight': 6.0}),
#  ('El_Hule', 'Ja', {'weight': 6.0}),
#  ('El_Hule', 'Peter', {'weight': 6.0}),
#  ('El_Hule', 'Theresa_Maria_Silveti', {'weight': 6.0}),
#  ('El_Hule', 'Veronica', {'weight': 6.0}),
#  ('Senor_Pla', 'Nanche', {'weight': 6.0}),
#  ('Cordoba', 'Valle_Royal', {'weight': 6.0}),
#  ('Valle_Royal', 'El_Mirador', {'weight': 6.0}),
#  ('Valle_Royal', 'Låra', {'weight': 6.0}),
#  ('El_Jefe', 'Maria_Sanchez', {'weight': 6.0}),
#  ('El_Mirador', 'Peter', {'weight': 6.0}),
#  ('Maria_Sanchez', 'Mexico_City', {'weight': 6.0}),
#  ('Veronica', 'Michelangelo', {'weight': 6.0})]

# %% [markdown]
# ## Draw graph without those edges
#
# Experiment with count parameter - green number

# %%
gnl.show_graph(g2.edge_subgraph(remove_edges(g2, 15)))

# %% [markdown]
# # Remove edges below a certain count

# %%
remove_edges(g2,6)
# Out:
# [('Balsa_Hermanos', 'Balsa_Hermanos-brødrene'),
#  ('Balsa_Hermanos-brødrene', 'Senor_Pla'),
#  ('El_Hule', 'Cordoba'),
#  ('El_Hule', 'El_Diablito'),
#  ('El_Hule', 'El_Jefe'),
#  ('El_Hule', 'El_Mirador'),
#  ('El_Hule', 'Herrera'),
#  ('El_Hule', 'Hondura'),
#  ('El_Hule', 'Låra'),
#  ('El_Hule', 'Maria_Sanchez'),
#  ('El_Hule', 'Mexico_City'),
#  ('El_Hule', 'Nanche'),
#  ('El_Hule', 'Senor_Pla'),
#  ('El_Hule', 'Tuztepec'),
#  ('El_Hule', 'Valle_Royal'),
#  ('Senor_Pla', 'El_Mirador'),
#  ('Senor_Pla', 'Herrera'),
#  ('Senor_Pla', 'Hondura'),
#  ('Senor_Pla', 'Låra'),
#  ('Senor_Pla', 'Maria_Sanchez'),
#  ('Senor_Pla', 'Mexico_City'),
#  ('Senor_Pla', 'Peter'),
#  ('Senor_Pla', 'Senor_Sanchez'),
#  ('Senor_Pla', 'Tresgallo'),
#  ('Senor_Pla', 'Valle_Royal'),
#  ('Cordoba', 'Tresgallo'),
#  ('Tresgallo', 'Valle_Royal'),
#  ('Valle_Royal', 'Hondura'),
#  ('Valle_Royal', 'Mexico_City'),
#  ('Valle_Royal', 'Nanche'),
#  ('Valle_Royal', 'Theresa_Maria_Silveti'),
#  ('El_Mirador', 'Låra'),
#  ('Hondura', 'Nanche'),
#  ('Låra', 'Mexico_City'),
#  ('Låra', 'Peter'),
#  ('Låra', 'Senor_Sanchez'),
#  ('Maria_Sanchez', 'Senor_Sanchez')]

# %%
gnl.show_communities(g2)
# Out:
# Balsa_Hermanos-brødrene-Balsa_Hermanos :  Balsa_Hermanos-brødrene, Balsa_Hermanos
#
# El_Hule-Cordoba :  El_Hule, Cordoba, El_Jefe, Tuztepec, Ja, El_Diablito
#
# Senor_Pla-Valle_Royal :  Senor_Pla, Valle_Royal, Mexico_City, Nanche, Hondura, Tresgallo, Theresa_Maria_Silveti, Herrera
#
# Låra-El_Mirador :  Låra, El_Mirador, Peter
#
# Maria_Sanchez-Senor_Sanchez :  Maria_Sanchez, Senor_Sanchez
#
# Veronica-Michelangelo :  Veronica, Michelangelo

# %%
gnl.community_dict(g2)
# Out:
# {'Balsa_Hermanos-brødrene-Balsa_Hermanos': ['Balsa_Hermanos-brødrene',
#   'Balsa_Hermanos'],
#  'El_Hule-Cordoba': ['El_Hule',
#   'Cordoba',
#   'El_Jefe',
#   'Tuztepec',
#   'Ja',
#   'El_Diablito'],
#  'Låra-El_Mirador': ['Låra', 'El_Mirador', 'Peter'],
#  'Maria_Sanchez-Senor_Sanchez': ['Maria_Sanchez', 'Senor_Sanchez'],
#  'Senor_Pla-Valle_Royal': ['Senor_Pla',
#   'Valle_Royal',
#   'Mexico_City',
#   'Nanche',
#   'Hondura',
#   'Tresgallo',
#   'Theresa_Maria_Silveti',
#   'Herrera'],
#  'Veronica-Michelangelo': ['Veronica', 'Michelangelo']}

# %%
wp_diagram = nb.plot_book_wordbags(BOOK,gnl.community_dict(g2) ,window=20000)

# %%
wp_diagram.rolling(window=10).mean().plot(figsize=(15,6), lw=3, alpha=0.7)

# %%
nb.plot_sammen_vekst??
