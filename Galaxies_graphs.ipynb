# %% [markdown]
# ### Preamble
#
# Contains imports and some utility code.

# %%
from dhlab.module_update import update, css, code_toggle

# %%
css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Merriweather';
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
#
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %%
import dhlab.graph_networkx_louvain as gnl
import dhlab.nbtext as nb
import networkx as nx
import pandas as pd
# %matplotlib inline

# %%
def frame_sort(frame, by=0):
    return frame.sort_values(by=by, ascending=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def centrality_bonanza(G):
    c1 = nb.frame(nx.katz_centrality(G), 'katz')
    c2 = nb.frame(nx.eigenvector_centrality(G),'eigenvector')
    c3 = nb.frame(nx.closeness_centrality(G), 'closeness')
    c4 = nb.frame(nx.degree_centrality(G), 'degree')
    c5 = nb.frame(nx.betweenness_centrality(G), 'betweenness')
    return pd.concat([c1, c2, c3, c4, c5], axis=1)

# %% [markdown]
# # Galaxies
#
# Norwegian from National Library, English and German from Google N-grams.
#
# Use it to analyse places, names, word hierarchies. Galaxies are a kind of word vectors constructed from trigrams on the form "X and Y" for English, "X og Y" for Norwegian, and "X und Y" for German. Recursively two depths.

# %%
ice = nb.make_graph('ice', lang='eng')

# %%
gnl.show_graph(ice, spread=0.5)

# %% [markdown]
# # Experiment with centrality measures
#
# Use command `centrality_bonanza(graph)`

# %%
ice_centralities = centrality_bonanza(ice)

# %%
nb.heatmap(frame_sort(ice_centralities, 'betweenness'))
# Out:
# <style  type="text/css" >
#     #T_29464dc0_711e_11eb_88bd_985fd3509bc7row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row0_col1 {
#             background-color:  #4fac4f;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row1_col0 {
#             background-color:  #309a30;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row1_col1 {
#             background-color:  #45a645;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row1_col2 {
#             background-color:  #45a645;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row1_col3 {
#             background-color:  #0e870e;
#             color:  #f1f1f1;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row1_col4 {
#             background-color:  #74c074;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row2_col0 {
#             background-color:  #1c8f1c;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row2_col2 {
#             background-color:  #229322;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row2_col3 {
#             background-color:  #2a972a;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row2_col4 {
#             background-color:  #89cc89;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row3_col0 {
#             background-color:  #44a544;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row3_col1 {
#             background-color:  #3da23d;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row3_col2 {
#             background-color:  #329c32;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row3_col3 {
#             background-color:  #47a747;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row3_col4 {
#             background-color:  #a3daa3;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row4_col0 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row4_col1 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row4_col2 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row4_col3 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row4_col4 {
#             background-color:  #a4dba4;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row5_col0 {
#             background-color:  #5db35d;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row5_col1 {
#             background-color:  #259425;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row5_col2 {
#             background-color:  #299729;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row5_col3 {
#             background-color:  #81c781;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row5_col4 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row6_col0 {
#             background-color:  #319b31;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row6_col1 {
#             background-color:  #1f911f;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row6_col2 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row6_col3 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row6_col4 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row7_col0 {
#             background-color:  #89cc89;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row7_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row7_col2 {
#             background-color:  #afe1af;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row7_col3 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row7_col4 {
#             background-color:  #b7e5b7;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row8_col0 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row8_col2 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row8_col3 {
#             background-color:  #56af56;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row8_col4 {
#             background-color:  #c6eec6;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row9_col0 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row9_col1 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row9_col2 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row9_col3 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row9_col4 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row10_col0 {
#             background-color:  #84c984;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row10_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row10_col2 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row10_col3 {
#             background-color:  #8fcf8f;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row10_col4 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row11_col0 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row11_col1 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row11_col2 {
#             background-color:  #3fa33f;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row11_col3 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_29464dc0_711e_11eb_88bd_985fd3509bc7row11_col4 {
#             background-color:  #daf9da;
#             color:  #0

# %%
Eis = nb.make_graph('Eis', lang='ger')

# %%
gnl.show_graph(Eis, spread=0.5)

# %% [markdown]
# # German has the drug reading!
#
# For any graph, use command `show_communities` from `gnl` to have a look at the clusters, or use `community_dict` for analytical purposes.

# %%
gnl.show_communities(Eis)
# Out:
# Kochsalz-Salpeter :  Kochsalz, Salpeter, Salmiak, Glaubersalz, Harnstoff, Alaun
#
# Opium-Haschisch :  Opium, Haschisch, Morphin, Belladonna, Morphium, Campher, Kampher
#
# Schnee-Reif :  Schnee, Reif, Firn, Hagel, Gletschereis, Graupeln, Nebel, Tau, Glatteis
#
# Gletscher-Gletschern :  Gletscher, Gletschern, Lawinen, Firnen, Eisberge, Firne, Inlandeis, Firnfeldern, Schneefelder, Firnfelder, Schneefeldern
#
# Eis-Hochwasser :  Eis, Hochwasser, Regen, Niedrigwasser, Schmelzwasser
#
# Frost-Kälte :  Frost, Kälte, Glut, Nässe, Eisgang, Hitze, Gefühllosigkeit, Asche, Zugluft, Schneefall, Tauwetter, Schneegestöber, Innigkeit
#
# Fels-Geröll :  Fels, Geröll, Hort, Schutt
#
# Kuchen-Limonade :  Kuchen, Limonade, Bier, Kaffee, Torten, Gebäck, Kekse

# %%
gnl.community_dict(Eis)
# Out:
# {'Kochsalz-Salpeter': ['Kochsalz',
#   'Salpeter',
#   'Salmiak',
#   'Glaubersalz',
#   'Harnstoff',
#   'Alaun'],
#  'Opium-Haschisch': ['Opium',
#   'Haschisch',
#   'Morphin',
#   'Belladonna',
#   'Morphium',
#   'Campher',
#   'Kampher'],
#  'Schnee-Reif': ['Schnee',
#   'Reif',
#   'Firn',
#   'Hagel',
#   'Gletschereis',
#   'Graupeln',
#   'Nebel',
#   'Tau',
#   'Glatteis'],
#  'Gletscher-Gletschern': ['Gletscher',
#   'Gletschern',
#   'Lawinen',
#   'Firnen',
#   'Eisberge',
#   'Firne',
#   'Inlandeis',
#   'Firnfeldern',
#   'Schneefelder',
#   'Firnfelder',
#   'Schneefeldern'],
#  'Eis-Hochwasser': ['Eis',
#   'Hochwasser',
#   'Regen',
#   'Niedrigwasser',
#   'Schmelzwasser'],
#  'Frost-Kälte': ['Frost',
#   'Kälte',
#   'Glut',
#   'Nässe',
#   'Eisgang',
#   'Hitze',
#   'Gefühllosigkeit',
#   'Asche',
#   'Zugluft',
#   'Schneefall',
#   'Tauwetter',
#   'Schneegestöber',
#   'Innigkeit'],
#  'Fels-Geröll': ['Fels', 'Geröll', 'Hort', 'Schutt'],
#  'Kuchen-Limonade': ['Kuchen',
#   'Limonade',
#   'Bier',
#   'Kaffee',
#   'Torten',
#   'Gebäck',
#   'Kekse']}

# %% [markdown]
# More than one word can be added

# %%
positive = nb.make_graph('good, nice, wedding, party', lang='eng')

# %%
gnl.show_graph(positive, spread=0.5)

# %%
gnl.show_communities(positive)
# Out:
# coronation-nuptials :  coronation, nuptials, consecration, anointing, investiture, unction, anointment, enthronement
#
# cosy-nice :  cosy, nice, cozy, neat, tidy, comfy, cosey, warm, snug, comfortable, homelike, toasty, homey, inviting, clean, shipshape, cleanly, quaint, homely, Warm, prim, dry, welcoming, trim, workmanlike, waterish
#
# contrivances-subtile :  contrivances, subtile, subtilties, disputes, refinements, stratagems, abstruse, inventions, artifices, expedients, craftie, makeshifts, knotty
#
# finical-squeamish :  finical, squeamish, fastidious, delicate, affected
#
# plunders-ravages :  plunders, ravages, robberies, robs, oppresses
#
# wedding-engagement :  wedding, engagement, honeymoon, betrothal, wooing, reception, courtship, marriage, Betrothal, Marriage, dowry, courting, Wedding, trousseaux, winning, interactivity, vacation, matrimony, impartation, disengagement, cooing, spectatorship, Courtship, musicale, soft, attentiveness, ceremony, sorrowe
#
# christening-birthdays :  christening, birthdays, baptismal, burial, weddings, funeral, baptism, launching, graduations, Birth, holidays, eucharistic, naming, christenings, namedays, Christmases, birth, anniversaries, confirmation, communion, Christmas, marrying, matrimonial
#
# chearfulness-hellos :  chearfulness, hellos, good, serenity, hugs, alacrity, gaiety, smiles, handshakes, goodbyes, joy, tenantable, husbandlike, spials
#
# naughty-disobedient :  naughty, disobedient, mischievous
#
# pigtails-tuxedos :  pigtails, tuxedos, hats, bangs, braces, pinafores, freckles, dresses
#
# party-officeholders :  party, officeholders, Komsomol, wranglings, soviet, Party, nonparty, beguiles, Communist, Partisanship, communists, Communists, bickerings, candidates, activists, Pioneer, deceives, komsomol, legislators, collective, heelers, union, Ideology, politicians, bosses, noisemakers, bureaucrats, voters, quarrels, Pioneers, hustlin, fraternally, Whips, Gibault, relator
#
# pemmican-cocoa :  pemmican, cocoa, biscuits, jerky, furs, biscuit
#
# catchwords-cliches :  catchwords, cliches, phrases, shibboleths, signatures, slogans
#
# bridesmaids-trousseau :  bridesmaids, trousseau, dowries, gowns, furniture, gifts, ushers, inheritances, presents, bridesmen, wills, gown, groomsmen, bride
#
# perfidy-treachery :  perfidy, treachery, baseness, ingratitude, cruelty, dissimulation, faithlessness, duplicity

# %%
Churchill_eng = nb.make_graph("Churchill", lang='eng')
Churchill_nob = nb.make_graph("Churchill", lang='nob')
Churchill_ger = nb.make_graph("Churchill", lang='ger')

# %%
gnl.show_graph(Churchill_eng, spread = 1.5)

# %%
gnl.show_graph(Churchill_ger, spread=0.7)

# %%
gnl.show_graph(Churchill_nob, spread=1.2)

# %% [markdown]
# # Exercise
#
# What about cities?
